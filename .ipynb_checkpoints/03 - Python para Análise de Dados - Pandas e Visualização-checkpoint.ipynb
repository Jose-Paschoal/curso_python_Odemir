# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
## ver início

df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
## ver se há linhas duplicadas

df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
### checar se há nulos

df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
### sumário estatístico

df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
### sumário estatístico - inclusive para as variáveis categóricas

df.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %%
## valores únicos 

df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
## frequência entre os gêneros

df.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
provas = ['math score', 'reading score', 'writing score']

# %%
## ordenar o dataset

df = df.sort_values(by = provas, ascending = False)\
.reset_index(drop = True)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group E           bachelor's degree      standard
# 1      male        group E           bachelor's degree      standard
# 2    female        group E          associate's degree      standard
# 3      male        group E          associate's degree  free/reduced
# 4      male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group C                some college  free/reduced
# 996  female        group B                some college      standard
# 997  female        group B            some high school  free/reduced
# 998  female        group B                 high school  free/reduced
# 999  female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
## coluna com a média das provas

df['mean'] = df[provas].mean(axis=1)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group E           bachelor's degree      standard
# 1    male        group E           bachelor's degree      standard
# 2  female        group E          associate's degree      standard
# 3    male        group E          associate's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none         100            100            100
# 1               completed         100            100            100
# 2                    none         100            100            100
# 3               completed         100            100             93
# 4               completed         100             97             99
#
#          mean
# 0  100.000000
# 1  100.000000
# 2  100.000000
# 3   97.666667
# 4   98.666667

# %%
## fazendo uma consulta no dataset

df.query('(gender == "male") & ("test preparation course" == "none") & ("math score" >= 70)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-c52795989713> in <module>
#       1 ## fazendo uma consulta no dataset
#       2
# ----> 3 df.query('(gender == "male") & ("test preparation course" == "none") & ("math score" >= 70)')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    4058         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4059         kwargs["target"] = None
# -> 4060         res = self.eval(expr, **kwargs)
#    4061
#    4062         try:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    4189         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    4190
# -> 4191         return _eval(expr, inplace=inplace, **kwargs)
#    4192
#    4193     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# ...

# %%
df[(df.gender == 'male') & (df['test preparation course'] == 'none') & (df['math score'] >= 70)]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 15    male        group C          associate's degree      standard
# 17    male        group E                some college      standard
# 23    male        group D             master's degree      standard
# 26    male        group E            some high school      standard
# 30    male        group E                 high school      standard
# ..     ...            ...                         ...           ...
# 401   male        group C                 high school      standard
# 403   male        group B                 high school      standard
# 406   male        group D                some college  free/reduced
# 407   male        group C                 high school      standard
# 408   male        group E                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 15                     none          97             93             91
# ...

# %%
## agrupamento -  agrupa os dados por gênero e obtém estatísticas descritivas

df.groupby(by = 'gender')[provas].agg([np.mean, np.median]).T
# Out:
# gender                   female       male
# math score    mean    63.633205  68.728216
#               median  65.000000  69.000000
# reading score mean    72.608108  65.473029
#               median  73.000000  66.000000
# writing score mean    72.467181  63.311203
#               median  74.000000  64.000000

# %% [markdown]
# ## Visualização de Dados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gráfico de Linhas

# %%
np.random.seed(7)

## vetor com números inteiros aleatórios entre 1, 1500 com 10 amostras

y = np.random.randint(low = 1, high= 1500, size = 10)

# %%
y
# Out:
# array([ 176, 1221,  538,  503,  212,  920, 1373, 1210, 1423,  536])

# %%
plt.plot(y)

# %%
## refinando o gráfico

# insere a primeira linha do plot

plt.plot(y, color = '#749187', marker = 'o', ms = 5, mec = 'k', markerfacecolor = 'w', ls = '-.')

# insere a segunda linha

plt.plot(y*2, marker = '+', color = 'k', ms = 5)

# rótulos 

plt.xlabel('Eixo x', color = 'red', size = 12)
plt.ylabel('Eixo y')
plt.title('Título', loc = 'left')

# gridlines

plt.grid(axis = 'y', color = 'gray', linestyle = '--', linewidth = 1, alpha = 0.8)

plt.show()

# %% [markdown]
# ### Subplots

# %%
np.random.seed(6)
x = np.arange(1, 11)
y1 = np.random.randint(1, 400, 10)
y2 = np.random.randint(150, 500, 10)
y3 = np.random.randint(200, 600, 10)

plt.figure(figsize = (15,5))
plt.suptitle('Figura', fontsize = 15)

plt.subplot(1,3,1)
plt.plot(x, y1, color = 'k')
plt.title('Subplot 1', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.subplot(1,3,2)
plt.plot(x, y2, color = 'r')
plt.title('Subplot 2', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.subplot(1,3,3)
plt.plot(x, y3, color = 'g')
plt.title('Subplot 3', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.tight_layout(pad = 4)
plt.show()

# %% [markdown]
# ### Histograma e Boxplot

# %%
df = np.random.normal(10, 0.5, 5000)
plt.hist(df)
plt.show()

# %%
plt.boxplot(df);

# %%
## scatter plot

x = np.random.normal(10, 0.5, 100)
y = np.random.uniform(0, 20, 100)

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y, marker = 'o', color = 'red', label = 'data 1', alpha = 0.5)
ax.scatter(x*0.5, y*0.5, marker ='v', color = 'black', label = 'data 2', alpha = 0.7)
ax.legend();

# %% [markdown]
# ## Utilizandos Dados Econômicos

# %%
import plotly.express as px

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
## gravando os dados em um df e utilizando uma quebra de filtro

df = px.data.gapminder().query('country == "Brazil"').set_index('year')

# %%
df.head()
# Out:
#      country continent  lifeExp        pop    gdpPercap iso_alpha  iso_num
# year
# 1952  Brazil  Americas   50.917   56602560  2108.944355       BRA       76
# 1957  Brazil  Americas   53.285   65551171  2487.365989       BRA       76
# 1962  Brazil  Americas   55.665   76039390  3336.585802       BRA       76
# 1967  Brazil  Americas   57.632   88049823  3429.864357       BRA       76
# 1972  Brazil  Americas   59.504  100840058  4985.711467       BRA       76

# %%
## Evolução do PIB per capita no tempo

plt.plot(df.index, df['gdpPercap'])
plt.title('PIB per capita do Brasil')
plt.ylabel('PIB per capita')
plt.xlabel('Tempo');

# %%
## Vendo relação entre expectativa de vida e renda per capita

title = 'Relação entre expectativa de vida e renda per capita no Brasil'

plt.figure(figsize = (12,4))
plt.scatter(df['lifeExp'], df['gdpPercap'], cmap= 'viridis')
plt.xlabel('Expectativa de vida')
plt.ylabel('Renda per capita')
plt.title(title, loc = 'left')
plt.show()

# %%
plt.bar(x = df.index, 
       height = df['pop'],
       color = 'red')

plt.title('População brasileira');

# %% [markdown]
# ## Checando Seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
## Definindo um tema

sns.set_theme(style = 'darkgrid')

# %%
## Dados do próprio Seaborn

dados = sns.load_dataset('tips')

# %%
dados
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Renomeando as colunas

dados.rename(columns ={'total_bill' : 'Total Conta', 'tip' : 'Gorjeta', 'sex' : 'Sexo', 'smoker' : 'Fumante', 'day' : 'Dia Semana', 'time' : 'Período', 'size' : 'Pessoas na Mesa'}, inplace = True)

# %%
dados.head()
# Out:
#    Total Conta  Gorjeta    Sexo Fumante Dia Semana Período  Pessoas na Mesa
# 0        16.99     1.01  Female      No        Sun  Dinner                2
# 1        10.34     1.66    Male      No        Sun  Dinner                3
# 2        21.01     3.50    Male      No        Sun  Dinner                3
# 3        23.68     3.31    Male      No        Sun  Dinner                2
# 4        24.59     3.61  Female      No        Sun  Dinner                4

# %%
# Gráfico Relplot

sns.relplot(x='Total Conta', y='Gorjeta', data = dados);

# %%
## Passando outro parâmetor como classe no gráfico

sns.relplot( x ='Total Conta', y = 'Gorjeta', data = dados, hue = 'Sexo');

# %%
## Mudando formato do gráfico

sns.relplot( x ='Total Conta', y = 'Gorjeta', data = dados, kind = 'line');

# %%
## Inserindo parâmetro dentro do gráfico no formato de linhas

sns.relplot( x ='Total Conta', y = 'Gorjeta', data = dados, kind = 'line', hue = 'Fumante');

# %% [markdown]
# ### Gráfico Histplot

# %%
sns.histplot(data = dados, x='Total Conta');

# %%
sns.histplot(data = dados, x='Total Conta', hue = 'Fumante');

# %% [markdown]
# ### Gráfico Barplot

# %%
sns.barplot(data = dados, x = 'Sexo', y = 'Total Conta', hue = 'Fumante');

# %% [markdown]
# ### Gráfico Pairplot

# %%
sns.pairplot(dados);

# %%
sns.pairplot(dados, hue = 'Sexo');

# %%
sns.pairplot(dados, kind = 'kde');

# %% [markdown]
# ### Gráfico Boxplot

# %%
sns.boxplot( data = dados, x = 'Dia Semana', y = 'Total Conta');

# %%
sns.boxplot( data = dados, x = 'Dia Semana', y = 'Total Conta', hue = 'Sexo');
